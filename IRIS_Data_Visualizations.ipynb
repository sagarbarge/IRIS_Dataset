# %% [markdown]
# # IRIS Data Visualizations

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **About Dataset:**
#
# The Iris dataset was used in R.A. Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems, and can also be found on the UCI Machine Learning Repository.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
#    - Id
#    - SepalLengthCm
#    - SepalWidthCm
#    - PetalLengthCm
#    - PetalWidthCm
#    - Species

# %% [markdown]
# Data Source: https://www.kaggle.com/datasets/uciml/iris

# %% [markdown]
# #### Import Liabraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# https://www.kaggle.com/code/benhamner/python-data-visualizations

# %% [markdown]
# #### Import Dataset

# %%
df = pd.read_csv('Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Basic Data Check

# %%
# Total rows & columns
df.shape
# Out:
# (150, 6)

# %%
# Species wise information

df.Species.value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
# Null Values

df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# - No Null values in dataset

# %%
# Count of duplicated rows

num_duplicate = df.duplicated().sum()
num_duplicate
# Out:
# 0

# %%
# data information()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# data basic statistics()
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# #### Data Visualization

# %% [markdown]
# #### Sepal

# %%
# Sepal Lenth vs width scatterplot with frequency

sns.jointplot(x="SepalLengthCm", y="SepalWidthCm", data=df,)
plt.show()

# %%
# Petal Lenth vs width scatterplot with frequency
sns.jointplot(x= 'PetalLengthCm', y='PetalWidthCm', data=df,)
plt.show()

# %%
# Sepal & Petal-  Lenth vs width scatterplot

plt.figure (figsize= (15,5))

# Sepal Lenth vs width scatterplot
plt.subplot (1,2,1)
sns.scatterplot(data= df, x= 'SepalLengthCm', y='SepalWidthCm', hue= 'Species')
plt.title('Scatterplot- Sepal Lenth vs Width ')

# Petal Lenth vs width scatterplot
plt.subplot (1,2,2)
sns.scatterplot(data= df, x= 'PetalLengthCm', y='PetalWidthCm', hue= 'Species')
plt.title('Scatterplot- Petal Lenth vs Width ')

plt.show()

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# - Observation:
# 1) Setosa Sepal's width is higher compare to other two spacies.
# 2)

# %%
# Boxplot to see species wise Petal Lengh-widh, Sepal Lenght-width for compairing

df.drop('Id', axis=1).boxplot(by='Species', figsize=(13,7))
plt.show()

# %%
# Pairplot of Iris data to see relationship between variable

sns.set_style('whitegrid')
sns.pairplot(data=df.drop('Id', axis=1), hue='Species')
plt.show()
